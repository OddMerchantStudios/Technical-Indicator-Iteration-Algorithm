# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import yfinance as yf
import hvplot.pandas
from pathlib import Path
from finta import TA
import matplotlib.pyplot as plt
import quantstats as qs
import itertools
from IPython.display import clear_output
from collections import Counter as CounterClass

# %%
pd.set_option('display.max_colwidth', None)

# %%
### Quant framework 3 x 3 x 3

#     Intraday   >>Swing<<    >>Position<<

#     Earnings     Event      >>TA<<

#   >>Delta<<      Theta        Vega

# Project 2 scope is focused on Swing and Position timeframe, while relying on TA
# to determine signals. Option strategies are not used.

### Technical goal:

# Automate creation and testing of new trading algorithms based on our framework

### Plan:

# 1. Pull the data: ohlc + volume ✓
# 2. Integrate Finta with our data ✓
# 3. Determine trading signals for testable indicators (crossovers, etc.)✓
# 4. Test the strategy on data of 2017 - 2019 
# 5. Automate testing of different combinations of strategies
# 6. Train ML algorithms on best performing strategies
# 7. Deploy trained ML algorithms and test performance on 2020-2023 data

# %%
sqrt = np.sqrt(252)
trading_days_year = 252
total_days_year = 365
thirty_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 30)).date()
ten_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 10)).date()
five_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 5)).date()
three_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 3)).date()
one_year = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 1)).date()
six_months = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year / 2)).date()
yesterday = (pd.Timestamp.today() - pd.Timedelta(days = 1)).date()
sixty_days = (pd.Timestamp.today() - pd.Timedelta(days = 59)).date()
# Portfolio vars

share_size = 100
initial_capital = 100000

# Optionable stocks 
optionable_stocks_path = Path('./Resources/optionable_stocks.csv')
with open(optionable_stocks_path, 'r') as file:
    optionable_stocks = file.read()
optionable_stocks = optionable_stocks.replace('\n', ' ')

# %% [markdown]
# # 1. Pull the data: ohlc + volume

# %%
def get_data(interval, start, end, seg_window = 21):
    yf_df = yf.Tickers(optionable_stocks)
    df_full =yf_df.history(start = start, end = end, interval= interval)
    stocks = df_full[['Open', 'Close', 'High', 'Low', 'Volume']]
    
    if interval == '5m':
        sqrt_val = 252 * 78 
    elif interval == '15m':
        sqrt_val = 252 * 26  
    elif interval == '30m':
        sqrt_val = 252 * 13 
    elif interval == '1h':
        sqrt_val = 252 * 6.5
    elif interval == '1d':
        sqrt_val = 252
    elif interval == '1wk':
        sqrt_val = 52
        
    stock_names = stocks.columns.get_level_values(1).unique().tolist()

    cumulative_return_column = pd.MultiIndex.from_product([['Rolling_Cumulative_Return'], stock_names])
    volatility_column = pd.MultiIndex.from_product([['Rolling_Volatility'], stock_names])
    sharpe_column = pd.MultiIndex.from_product([['Rolling_Sharpe'], stock_names])
    rank_column = pd.MultiIndex.from_product([['Rank_Sharpe'], stock_names])
    
    df_cumulative_return = pd.DataFrame(0.0, index = stocks.index , columns = cumulative_return_column)
    df_volatility = pd.DataFrame(0.0, index = stocks.index , columns = volatility_column )
    df_sharpe = pd.DataFrame(0.0, index = stocks.index , columns = sharpe_column)
    df_rank = pd.DataFrame(0.0, index = stocks.index , columns = sharpe_column)
    
    for stock in stock_names:
        mask = stocks.columns.get_level_values(1) == stock
        data = stocks.loc[:, mask]
        data.columns = data.columns.droplevel(1)
        close = data['Close']
        returns = data['Close'].pct_change()
        df_cumulative_return[('Rolling_Cumulative_Return', stock)] = (1 + returns).rolling(window=seg_window).apply(lambda x: x.prod())
        df_volatility[('Rolling_Volatility', stock)] = returns.rolling(window=seg_window).std() * np.sqrt(sqrt_val)
        df_sharpe[('Rolling_Sharpe', stock)] = (returns.rolling(window=seg_window).mean() * sqrt_val) / df_volatility[('Rolling_Volatility', stock)]
        
    def rank_row(row):
        return row.rank(ascending=False)

    df_rank = df_sharpe.apply(rank_row, axis=1)
    df_rank.columns = rank_column
    
    final_df = pd.concat([stocks, df_rank], axis = 1)
    
    return final_df

# %%
def get_individual_stock(stock, stocks):
    mask = stocks.columns.get_level_values(1) == stock
    data = stocks.loc[:, mask]
    data.columns = data.columns.droplevel(1)
    data.dropna(inplace = True)
    return data

# %%
# Pulls data for different time intervals. YF only provides last 60 days worth of intraday data

stocks_1wk = get_data('1wk', '2017-01-01', yesterday)
stocks_1d = get_data('1d', '2017-01-01', yesterday)
stocks_1h = get_data('1h', sixty_days, yesterday)
stocks_30m = get_data('30m', sixty_days, yesterday)
stocks_15m = get_data('15m', sixty_days, yesterday)
stocks_5m = get_data('5m', sixty_days, yesterday)

# gets valid stock names that we can iterate over in Tester()
stock_names = stocks_1d.columns.get_level_values(1).unique().tolist()
# Out:
# [*********************100%***********************]  95 of 95 completed
# [*********************100%***********************]  95 of 95 completed
# [*********************100%***********************]  95 of 95 completed
# [*********************100%***********************]  95 of 95 completed
# [*********************100%***********************]  95 of 95 completed
# [*********************100%***********************]  95 of 95 completed

# %% [markdown]
# # 2. Integrate Finta with our data

# %% [markdown]
# ## Getting indicators demo
# ### Once we have the finalized list of indicators, I will combine them into one function

# %%
# EMA
short_window = 8
long_window = 21
df = get_individual_stock('TSLA', stocks_1d)
df[f'EMA_{short_window}'] = TA.EMA(df, short_window)
df[f'EMA_{long_window}'] = TA.EMA(df, long_window)
df[['Close', 'EMA_8', 'EMA_21']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# BBANDS
df[['BB_UPPER','BB_MIDDLE','BB_LOWER']] = TA.BBANDS(df)
df[['Close', 'BB_UPPER','BB_MIDDLE','BB_LOWER']].plot(figsize = (25,7))

# Keltner Channels
df[['KC_UPPER', 'KC_LOWER']] = TA.KC(df)
df[['Close', 'KC_UPPER', 'KC_LOWER']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# ADX
df['ADX'] = TA.ADX(df)
df[['Close','ADX']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# MACD
df[['MACD', 'SIGNAL']] = TA.MACD(df)

df[['MACD', 'SIGNAL']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df['SQZMI'] = TA.SQZMI(df)
# Filter the DataFrame based on SQZMI values
false_df = df[df['SQZMI'] == False]
true_df = df[df['SQZMI'] == True]

# Extract the Close values
false_close_values = false_df['Close']
true_close_values = true_df['Close']

# Set the figure size
plt.figure(figsize=(25, 7))  # Adjust the width and height as desired

# Plot the values
plt.plot(false_close_values, color='green', label='SQZMI: False')
plt.scatter(true_df.index, true_close_values, color='red', label='SQZMI: True')
plt.xlabel('Index')
plt.ylabel('Close')
plt.title("Close values with line plot for SQZMI: False and scatter plot for SQZMI: True")
plt.legend()
plt.show()

# %% [markdown]
# # 3. Determine trading signals for testable indicators (crossovers, etc.)

# %% [markdown]
# # Get data for different intervals

# %% [markdown]
# # Iterator Class

# %%
# Define a class
class SignalIterator:
    
    # lower bound = has to be lower than this number, upper bound = has to be higher than this number
    def __init__(self, ticker, interval, stocks_df, lower_segment_boundary = 31, upper_segment_boundary = 0):
        
        if interval == '5m':
            self.sqrt_val = 252 * 78 
        elif interval == '15m':
            self.sqrt_val = 252 * 26  
        elif interval == '30m':
            self.sqrt_val = 252 * 13 
        elif interval == '1h':
            self.sqrt_val = 252 * 6.5
        elif interval == '1d':
            self.sqrt_val = 252
        elif interval == '1wk':
            self.sqrt_val = 52
            
        print(self.sqrt_val)
        
        self.lower_bound = lower_segment_boundary
        self.upper_bound = upper_segment_boundary
        self.stocks_df = stocks_df
        self.interval = interval
        self.ticker = ticker
        
        # Call the basic methods in the __init__ constructor to be immediately executed
        
        self.get_individual_stock()
        self.indicators()
        self.signals()

    def get_individual_stock(self):
        mask = self.stocks_df.columns.get_level_values(1) == self.ticker
        self.df = self.stocks_df.loc[:, mask]
        self.df.columns = self.df.columns.droplevel(1)
        self.df.dropna(inplace = True, axis = 0)
        
    def indicators(self):
        
        # EMA
        self.df['EMA_10'] = TA.EMA(self.df, 10)
        
        # EMA
        self.df['EMA_20'] = TA.EMA(self.df, 20)
        
         # EMA
        self.df['EMA_50'] = TA.EMA(self.df, 50)
        
        # BBANDS
        self.df[['BB_UPPER','BB_MIDDLE','BB_LOWER']] = TA.BBANDS(self.df, std_multiplier= 3)
        
        # SQZ setup
        self.df['SQZ'] = TA.SQZMI(self.df)
        
        # ADX
        self.df['ADX'] = TA.ADX(self.df)
        self.df['ADX_MEAN'] = self.df['ADX'].rolling(window = 90).mean()
        
        # MACD
        self.df[['MACD', 'SIGNAL']] = TA.MACD(self.df)
        
        # CHAIKIN
        self.df['CHAIKIN'] = TA.CHAIKIN(self.df)
        
        # MFI
        self.df['MFI'] = TA.MFI(self.df)
   
    def signals(self):
        
        ### SEGMENTATION ###
        
        self.df['Segmentation_Signal'] = 0.0
        self.df['Segmentation_Signal'] = np.where(
        (self.df['Rank_Sharpe'] <= self.lower_bound) & (self.df['Rank_Sharpe'] >= self.upper_bound), 1.0, 0.0)
        
        ### BUY SIGNALS ###
        
        # EMA Signal logic
        self.df['EMA20_Signal'] = 0.0
        self.df['EMA20_Signal'] = np.where((self.df['Close'] > self.df['EMA_20']), 1.0, 0.0)
        
        # EMA Signal logic
        self.df['EMA50_Signal'] = 0.0
        self.df['EMA50_Signal'] = np.where((self.df['Close'] > self.df['EMA_50']), 1.0, 0.0)
        
        # SQZ Signal logic
        self.df['SQZ_Signal'] = 0.0
        self.df['SQZ_Signal'] = np.where(self.df['SQZ'] == False, 1.0, 0.0)
        
        # ADX Signal logic
        self.df['ADX_Signal'] = 0.0
        self.df['ADX_Signal'] = np.where(self.df['ADX'] > self.df['ADX_MEAN'], 1.0, 0.0)
        
        # MACD Signal logic
        self.df['MACD_Signal'] = 0.0
        self.df['MACD_Signal'] = np.where(self.df['MACD'] > self.df['SIGNAL'], 1.0, 0.0)        
        
        # CHAIKIN Signal logic
        self.df['CHAIKIN_Signal'] = 0.0
        self.df['CHAIKIN_Signal'] = np.where(self.df['CHAIKIN'] > 0, 1.0, 0.0)        
        
        # MFI Signal logic
        self.df['MFI_Signal'] = 0.0
        self.df['MFI_Signal'] = np.where(self.df['MFI'] < 20, 1.0, 0.0)    
        
        ### SELL SIGNALS ###
        
        # BBANDS Sell Signal Logic
        self.df['BB_Sell_Signal'] = 0.0
        self.df['BB_Sell_Signal'] = np.where((self.df['Close'] > self.df['BB_UPPER']), 0.0, 1.0)        
        
    def result(self):
        
        eval_df = pd.DataFrame()
        
        # Define the signal column names
        buy_signal_columns = ['EMA50_Signal','EMA20_Signal','MACD_Signal','SQZ_Signal','CHAIKIN_Signal','MFI_Signal']
        sell_signal_columns = ['BB_Sell_Signal','EMA20_Signal', 'MACD_Signal','ADX_Signal']
        
        # Generate all combinations of signal columns
        for r_buy in range(1, len(buy_signal_columns) + 1):
            combinations_buy = list(itertools.combinations(buy_signal_columns, r_buy))

            # Generate all combinations of sell signal columns
            for r_sell in range(1, len(sell_signal_columns) + 1):
                combinations_sell = list(itertools.combinations(sell_signal_columns, r_sell))

                # Iterate over each combination of buy and sell signals
                for combo_buy in combinations_buy:
                    selected_buy_columns = list(combo_buy)
                    selected_buy_columns.append('Segmentation_Signal')
                    
                    for combo_sell in combinations_sell:
                        selected_sell_columns = list(combo_sell)

                        # Initialize the first row of Main_Signal as 0
                        self.df['Main_Signal'] = 0.0
                        self.df['Portfolio Daily Returns'] = 0.0

                        main_signal = self.df['Main_Signal'].values
                        buy_signal_arr = self.df[selected_buy_columns].values
                        sell_signal_arr = self.df[selected_sell_columns].values
                        close = self.df['Close'].values
                        daily_ret = self.df['Portfolio Daily Returns'].values

                        # Iterate over the remaining rows
                        for i in range(1, self.df.shape[0]):
                            previous_signal = main_signal[i - 1]

                            if previous_signal == 0:
                                # Use Buy Signals to determine current signal
                                buy_signal_conditions = np.all(buy_signal_arr[i] == 1)
                                sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                                main_signal[i] = int(buy_signal_conditions & sell_signal_conditions)

                                # returns logic
                                daily_ret[i] = 0.0

                            else:
                                # Use Sell Signals to determine current signal
                                sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                                main_signal[i] = int(sell_signal_conditions)

                                # returns logic
                                previous_price = close[i - 1]
                                current_price = close[i]
                                daily_ret[i] = (current_price - previous_price) / previous_price

                        # Entry/Exit logic
                        self.df['Main_Signal'] = main_signal

                        # Performance Metrics
                        self.df['Entry/Exit'] = self.df['Main_Signal'].diff()
                        self.df['Portfolio Daily Returns'] = daily_ret
                        self.df['Portfolio Cumulative Returns'] = (1 + self.df["Portfolio Daily Returns"]).cumprod()
                        self.df['Buy And Hold Return'] = (1 + self.df['Close'].pct_change()).cumprod()

                        # Create a df with performance summary for each combination

                        # append evaluation metrics to a df as a new row
                        ann_ret =  self.df['Portfolio Daily Returns'].mean() * self.sqrt_val
                        cum_ret = self.df['Portfolio Cumulative Returns'].iloc[-1]
                        ann_volat = self.df['Portfolio Daily Returns'].std() * np.sqrt(self.sqrt_val)
                        sharpe = ann_ret / ann_volat
                        buy_and_hold = self.df['Buy And Hold Return'].iloc[-1]
                        bnh_volatility = self.df['Close'].pct_change().std() * np.sqrt(self.sqrt_val)
                        bnh_sharpe = (self.df['Close'].pct_change().mean()* self.sqrt_val) / bnh_volatility
                        
                        new_row = {'Buy Signals' : f'{selected_buy_columns}',
                                   'Sell Signals' : f'{selected_sell_columns}',
                                   'Algo Annualized Return' : ann_ret,
                                   'Algo Cumulative Return' : cum_ret,
                                   'Algo Annual Volatility' : ann_volat,
                                   'Algo Sharpe Ratio' : sharpe,
                                   'BNH Cumulative Return': buy_and_hold,
                                   'BNH Volatility' : bnh_volatility,
                                   'BNH Sharpe' : bnh_sharpe,
                                   'Ticker': self.ticker}
                        
                        eval_df = eval_df.append(new_row, ignore_index=True)
                        
                        #clear_output(wait=True)
                        #print(f'{selected_buy_columns} & {selected_sell_columns}')

        self.filtered_df = eval_df.sort_values('Algo Cumulative Return', ascending = False)
        return self.filtered_df 

    def plot_top_strategy(self):
        top_5_strategies = self.filtered_df.head()

        # Iterate over each row in the top 5 strategies
        for index, row in top_5_strategies.iterrows():
            # Create a new figure for each strategy
            plt.figure(figsize=(25, 10))

            # Get the strategy name
            ticker = row['Ticker']
            selected_buy_columns = eval(row['Buy Signals'])
            selected_sell_columns = eval(row['Sell Signals'])

            # Initialize the first row of Main_Signal as 0
            self.df['Main_Signal'] = 0.0
            self.df['Portfolio Daily Returns'] = 0.0

            main_signal = self.df['Main_Signal'].values
            buy_signal_arr = self.df[selected_buy_columns].values
            sell_signal_arr = self.df[selected_sell_columns].values
            close = self.df['Close'].values
            daily_ret = self.df['Portfolio Daily Returns'].values

            # Iterate over the remaining rows
            for i in range(1, self.df.shape[0]):
                previous_signal = main_signal[i - 1]

                if previous_signal == 0:
                    # Use Buy Signals to determine current signal
                    buy_signal_conditions = np.all(buy_signal_arr[i] == 1)
                    sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                    main_signal[i] = int(buy_signal_conditions & sell_signal_conditions)

                    # returns logic
                    daily_ret[i] = 0.0

                else:
                    # Use Sell Signals to determine current signal
                    sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                    main_signal[i] = int(sell_signal_conditions)

                    # returns logic
                    previous_price = close[i - 1]
                    current_price = close[i]
                    daily_ret[i] = (current_price - previous_price) / previous_price

            # Entry/Exit logic
            self.df['Main_Signal'] = main_signal

            # Performance Metrics
            self.df['Entry/Exit'] = self.df['Main_Signal'].diff()
            self.df['Portfolio Daily Returns'] = daily_ret
            self.df['Portfolio Cumulative Returns'] = (1 + self.df["Portfolio Daily Returns"]).cumprod()
            self.df['Buy And Hold Return'] = (1 + self.df['Close'].pct_change()).cumprod()

            # Create a new figure for each strategy
            plt.figure(figsize=(25, 10))

            # Get the entry/exit signal
            entry_exit = self.df['Entry/Exit']
            bnh = self.df['Buy And Hold Return']
            close = self.df['Close']

            portfolio_cumulative_returns = self.df['Portfolio Cumulative Returns']

            # Plot the portfolio cumulative returns
            plt.plot(bnh, label=f'{self.ticker} Cumulative Return')
            plt.plot(portfolio_cumulative_returns, label='Portfolio Cumulative Returns')

            # Plot the entry points as vertical lines
            for entry_index in entry_exit[entry_exit == 1].index:
                plt.axvline(entry_index, color='g', linestyle='--')

            # Plot the exit points as vertical lines
            for exit_index in entry_exit[entry_exit == -1].index:
                plt.axvline(exit_index, color='r', linestyle='--')

            # Set the plot title and labels
            plt.title(f'Buy: {selected_buy_columns} & Sell: {selected_sell_columns}')
            plt.xlabel("Time")
            plt.ylabel("Price")
            plt.legend()

            # Show the plot for the current strategy
            plt.show()

# %% [markdown]
# # Bespoke Strategy Class

# %%
# Define a class
class BespokeStrategy:
    
    def __init__(self, ticker, interval, stocks_df, buy_signals = [], sell_signals = [] , lower_segment_boundary = 31, upper_segment_boundary = 0):
        
        if interval == '5m':
            self.sqrt_val = 252 * 78 
        elif interval == '15m':
            self.sqrt_val = 252 * 26  
        elif interval == '30m':
            self.sqrt_val = 252 * 13 
        elif interval == '1h':
            self.sqrt_val = 252 * 6.5
        elif interval == '1d':
            self.sqrt_val = 252
        elif interval == '1wk':
            self.sqrt_val = 52
            
        buy_signals.append('Segmentation_Signal')
        self.buy_signals = buy_signals 
        self.sell_signals = sell_signals
        self.lower_bound = lower_segment_boundary
        self.upper_bound = upper_segment_boundary   
        self.stocks_df = stocks_df
        self.interval = interval
        self.ticker = ticker
        
        # Call the basic methods in the __init__ constructor to be immediately executed
        
        self.get_individual_stock()
        self.indicators()
        self.signals()

    def get_individual_stock(self):
        mask = self.stocks_df.columns.get_level_values(1) == self.ticker
        self.df = self.stocks_df.loc[:, mask]
        self.df.columns = self.df.columns.droplevel(1)
        self.df.dropna(inplace = True, axis = 0)
        
    def indicators(self):
        
        # EMA
        self.df['EMA_10'] = TA.EMA(self.df, 10)
        
        # EMA
        self.df['EMA_20'] = TA.EMA(self.df, 20)
        
         # EMA
        self.df['EMA_50'] = TA.EMA(self.df, 50)
        
        # BBANDS
        self.df[['BB_UPPER','BB_MIDDLE','BB_LOWER']] = TA.BBANDS(self.df, std_multiplier= 3)
        
        # SQZ setup
        self.df['SQZ'] = TA.SQZMI(self.df)
        
        # ADX
        self.df['ADX'] = TA.ADX(self.df)
        self.df['ADX_MEAN'] = self.df['ADX'].rolling(window = 90).mean()
        
        # MACD
        self.df[['MACD', 'SIGNAL']] = TA.MACD(self.df)
        
        # CHAIKIN
        self.df['CHAIKIN'] = TA.CHAIKIN(self.df)
        
        # MFI
        self.df['MFI'] = TA.MFI(self.df)
   
    def signals(self):
        
        ### SEGMENTATION ###
        
        self.df['Segmentation_Signal'] = 0.0
        self.df['Segmentation_Signal'] = np.where(
        (self.df['Rank_Sharpe'] <= self.lower_bound) & (self.df['Rank_Sharpe'] >= self.upper_bound), 1.0, 0.0)
        
        ### BUY SIGNALS ###
        
        # EMA Signal logic
        self.df['EMA20_Signal'] = 0.0
        self.df['EMA20_Signal'] = np.where((self.df['Close'] > self.df['EMA_20']), 1.0, 0.0)
        
        # EMA Signal logic
        self.df['EMA50_Signal'] = 0.0
        self.df['EMA50_Signal'] = np.where((self.df['Close'] > self.df['EMA_50']), 1.0, 0.0)
        
        # SQZ Signal logic
        self.df['SQZ_Signal'] = 0.0
        self.df['SQZ_Signal'] = np.where(self.df['SQZ'] == False, 1.0, 0.0)
        
        # ADX Signal logic
        self.df['ADX_Signal'] = 0.0
        self.df['ADX_Signal'] = np.where(self.df['ADX'] > self.df['ADX_MEAN'], 1.0, 0.0)
        
        # MACD Signal logic
        self.df['MACD_Signal'] = 0.0
        self.df['MACD_Signal'] = np.where(self.df['MACD'] > self.df['SIGNAL'], 1.0, 0.0)        
        
        # CHAIKIN Signal logic
        self.df['CHAIKIN_Signal'] = 0.0
        self.df['CHAIKIN_Signal'] = np.where(self.df['CHAIKIN'] > 0, 1.0, 0.0)        
        
        # MFI Signal logic
        self.df['MFI_Signal'] = 0.0
        self.df['MFI_Signal'] = np.where(self.df['MFI'] < 20, 1.0, 0.0)    
        
        ### SELL SIGNALS ###
        
        # BBANDS Sell Signal Logic
        self.df['BB_Sell_Signal'] = 0.0
        self.df['BB_Sell_Signal'] = np.where((self.df['Close'] > self.df['BB_UPPER']), 0.0, 1.0)  
        
    def result(self):
        
        self.eval_df = pd.DataFrame()
        
        # Define the signal column names
        buy_signal_columns = self.buy_signals
        sell_signal_columns = self.sell_signals
        
        # Initialize the first row of Main_Signal as 0
        self.df['Main_Signal'] = 0.0
        self.df['Portfolio Daily Returns'] = 0.0
        
        main_signal = self.df['Main_Signal'].values
        buy_signal_arr = self.df[buy_signal_columns].values
        sell_signal_arr = self.df[sell_signal_columns].values
        close = self.df['Close'].values
        daily_ret = self.df['Portfolio Daily Returns'].values
        
        # Iterate over the remaining rows
        for i in range(1, self.df.shape[0]):
            previous_signal = main_signal[i - 1]
            
            if previous_signal == 0:
                # Use Buy Signals to determine current signal
                buy_signal_conditions = np.all(buy_signal_arr[i] == 1)
                sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                main_signal[i] = int(buy_signal_conditions & sell_signal_conditions)
                
                # returns logic
                daily_ret[i] = 0.0
                
            else:
                # Use Sell Signals to determine current signal
                sell_signal_conditions = np.all(sell_signal_arr[i] == 1)
                main_signal[i] = int(sell_signal_conditions)
                
                # returns logic
                previous_price = close[i - 1]
                current_price = close[i]
                daily_ret[i] = (current_price - previous_price) / previous_price
                
        # Entry/Exit logic
        self.df['Main_Signal'] = main_signal

        # Performance Metrics
        self.df['Entry/Exit'] = self.df['Main_Signal'].diff()
        self.df['Portfolio Daily Returns'] = daily_ret
        self.df['Portfolio Cumulative Returns'] = (1 + self.df["Portfolio Daily Returns"]).cumprod()
        self.df['Buy And Hold Return'] = (1 + self.df['Close'].pct_change()).cumprod()

        # Create a df with performance summary for each combination

        # append evaluation metrics to a df as a new row
        ann_ret =  self.df['Portfolio Daily Returns'].mean() * self.sqrt_val
        cum_ret = self.df['Portfolio Cumulative Returns'].iloc[-1]
        ann_volat = self.df['Portfolio Daily Returns'].std() * np.sqrt(self.sqrt_val)
        sharpe = ann_ret / ann_volat
        buy_and_hold = self.df['Buy And Hold Return'].iloc[-1]
        bnh_volatility = self.df['Close'].pct_change().std() * np.sqrt(self.sqrt_val)
        bnh_sharpe = (self.df['Close'].pct_change().mean()* self.sqrt_val) / bnh_volatility

        new_row = {'Buy Signals' : f'{buy_signal_columns}',
                   'Sell Signals' : f'{sell_signal_columns}',
                   'Algo Annualized Return' : ann_ret,
                   'Algo Cumulative Return' : cum_ret,
                   'Algo Annual Volatility' : ann_volat,
                   'Algo Sharpe Ratio' : sharpe,
                   'BNH Cumulative Return': buy_and_hold,
                   'BNH Volatility' : bnh_volatility,
                   'BNH Sharpe' : bnh_sharpe,
                   'Ticker': self.ticker}
        
        self.eval_df = self.eval_df.append(new_row, ignore_index=True)
        
        return self.eval_df

    def plot_strategy(self):

        # Create a new figure for each strategy
        plt.figure(figsize=(25, 10))
        
        # Get the entry/exit signal
        entry_exit = self.df['Entry/Exit']
        bnh = self.df['Buy And Hold Return']
        close = self.df['Close']
        #rolling_sharpe = self.df['Rolling_Sharpe']
        
        portfolio_cumulative_returns = self.df['Portfolio Cumulative Returns']
        
        # Plot the portfolio cumulative returns
        plt.plot(bnh, label=f'{self.ticker} Cumulative Return')
        plt.plot(portfolio_cumulative_returns, label='Portfolio Cumulative Returns')
        #plt.plot(rolling_sharpe, label='Rolling Sharpe')
        
        # Plot the entry points as vertical lines
        for entry_index in entry_exit[entry_exit == 1].index:
            plt.axvline(entry_index, color='g', linestyle='--')

        # Plot the exit points as vertical lines
        for exit_index in entry_exit[entry_exit == -1].index:
            plt.axvline(exit_index, color='r', linestyle='--')

        # Set the plot title and labels
        plt.title("Strategy - Entry/Exits")
        plt.xlabel("Time")
        plt.ylabel("Return")
        plt.legend()

        # Show the plot for the current strategy
        plt.show()
    def stats(self):
        return qs.reports.basic(self.df['Portfolio Daily Returns'])

# %% [markdown]
# # Tester Class

# %%
# class to test different strategies            
class Tester:
    """
    lower bound = has to be lower than this number
    upper bound = has to be higher than this number
    
    self.df['Segmentation_Signal'] = np.where(
    (self.df['Rank_Sharpe'] <= self.lower_bound) & (self.df['Rank_Sharpe'] >= self.upper_bound), 1.0, 0.0)
    
    lower_bound = 62
    upper_bound = 0
    0 < Rank < 62
    """
    def __init__(self, interval, stocks_df, stock_list, lower_segment_boundary = 31, upper_segment_boundary = 0):
        
        self.stock_list = stock_list
        self.interval = interval
        self.stocks_data = stocks_df
        self.lower = lower_segment_boundary
        self.upper = upper_segment_boundary
        
        self.backtest_on_stocks()
        self.top_return()
        self.top_sharpe()
        
    def backtest_on_stocks(self):
        self.combined = pd.DataFrame()
        for index, stock in enumerate(self.stock_list):
            self.iterator = SignalIterator(stock, interval = self.interval, stocks_df = self.stocks_data, lower_segment_boundary = self.lower, upper_segment_boundary=self.upper)
            result = self.iterator.result()
            self.combined = pd.concat([self.combined, result], axis=0)
            clear_output(wait=True)
            print(f'{stock} analysis complete ({index+1}/{len(self.stock_list)})')
    
    def top_return(self):     
        return self.combined.sort_values('Algo Cumulative Return', ascending= False).head(15)
    
    def top_sharpe(self):
        return self.combined.sort_values('Algo Sharpe Ratio', ascending= False).head(15)
    
    def full(self):
        return self.combined

# %% [markdown]
# # Daily Data, 21 Day Sharpe Lookback

# %% [markdown]
# ### Running iterator on different segmentation buckets...

# %% [markdown]
# ## No Segmentation

# %%
tester_no_seg = Tester(stocks_df= stocks_1d, interval = '1d', stock_list= stock_names, lower_segment_boundary= 100, upper_segment_boundary= 0)
tester_no_seg_top_return = tester_no_seg.top_return()
tester_no_seg_top_sharpe = tester_no_seg.top_sharpe()
tester_no_seg_full = tester_no_seg.full()

# %% [markdown]
# ## Top 30% Sharpe

# %%
tester_top_30_percent = Tester(stocks_df= stocks_1d, interval = '1d', stock_list= stock_names, lower_segment_boundary= 31, upper_segment_boundary= 0)

tester_top_30_percent_top_return = tester_top_30_percent.top_return()
tester_top_30_percent_top_sharpe = tester_top_30_percent.top_sharpe()
tester_top_30_percent_full = tester_top_30_percent.full()

# %% [markdown]
# ## Top 30 - 60 % Sharpe

# %%
tester_30_60_middle = Tester(stocks_df= stocks_1d, interval = '1d', stock_list= stock_names, lower_segment_boundary= 62, upper_segment_boundary= 31)

tester_30_60_top_return = tester_30_60_middle.top_return()
tester_30_60_top_sharpe = tester_30_60_middle.top_sharpe()
tester_30_60_full = tester_30_60_middle.full()

# %% [markdown]
# ## Bottom 30% Sharpe

# %%
tester_bottom_30_percent = Tester(stocks_df= stocks_1d, interval = '1d', stock_list= stock_names, lower_segment_boundary= 100, upper_segment_boundary= 62)

tester_bottom_30_percent_top_return = tester_bottom_30_percent.top_return()
tester_bottom_30_percent_top_sharpe = tester_bottom_30_percent.top_sharpe()
tester_bottom_30_percent_full = tester_bottom_30_percent.full()

# %% [markdown]
# ## Top 60% Sharpe

# %%
tester_top_60_percent = Tester(stocks_df= stocks_1d, interval = '1d', stock_list= stock_names, lower_segment_boundary = 62, upper_segment_boundary= 0)

tester_top_60_percent_top_return = tester_top_60_percent.top_return()
tester_top_60_percent_top_sharpe = tester_top_60_percent.top_sharpe()
tester_top_60_percent_full = tester_top_60_percent.full()

# %% [markdown]
# # Data visualisation

# %%
def plot_algo_vs_bnh_return(df, note = ''):
    

    df = df.reset_index(drop=True)
    top_strategy_indexes = df.groupby('Ticker')['Algo Cumulative Return'].idxmax()
    
    df = df.loc[top_strategy_indexes]

    df = df.loc[:, ['Ticker', 'Algo Cumulative Return', 'BNH Cumulative Return']].sort_values('BNH Cumulative Return')
    
    c1= df['Algo Cumulative Return'].hvplot.bar(title = f'Best Algo Return vs BNH Return {note}',
                                                rot = 45,
                                                width = 2000,
                                                height = 700,
                                                color = 'white',
                                                hover_color = 'cyan',
                                                alpha = 0.6,
                                                xlabel = 'Ticker')
    c2= df['BNH Cumulative Return'].hvplot.bar(title = f'Best Algo Return vs BNH Return {note}',
                                                rot = 45,
                                                width = 2000,
                                                height = 700,
                                                color = 'black',
                                                hover_color = 'magenta',
                                                alpha = 0.6,
                                                xlabel = 'Ticker')
    return c1 * c2

# %%
def plot_algo_vs_bnh_sharpe(df, note = ''):
    
    df = df.reset_index(drop=True)
    top_strategy_indexes = df.groupby('Ticker')['Algo Sharpe Ratio'].idxmax()
    
    df = df.loc[top_strategy_indexes]

    df = df.loc[:, ['Ticker', 'Algo Sharpe Ratio', 'BNH Sharpe']].sort_values('BNH Sharpe')

    c1= df['Algo Sharpe Ratio'].hvplot.bar(title = f'Best Algo Sharpe vs BNH Sharpe {note}',
                                                rot = 45,
                                                width = 2000,
                                                height = 700,
                                                color = 'white',
                                                hover_color = 'cyan',
                                                alpha = 0.6,
                                                xlabel = 'Ticker')
    c2= df['BNH Sharpe'].hvplot.bar(title = f'Best Algo Sharpe vs BNH Sharpe {note}',
                                                rot = 45,
                                                width = 2000,
                                                height = 700,
                                                color = 'black',
                                                hover_color = 'magenta',
                                                alpha = 0.6,
                                                xlabel = 'Ticker')
    return c1 * c2

# %% [markdown]
# ## Algo vs Buy and Hold Returns

# %%
plot_algo_vs_bnh_return(tester_no_seg_full, '(No Segmentation)')
# Out:
# :Overlay
#    .Bars.Algo_Cumulative_Return :Bars   [index]   (Algo Cumulative Return)
#    .Bars.BNH_Cumulative_Return  :Bars   [index]   (BNH Cumulative Return)

# %%
plot_algo_vs_bnh_return(tester_top_30_percent_full, '(Segment: Top 30% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Cumulative_Return :Bars   [index]   (Algo Cumulative Return)
#    .Bars.BNH_Cumulative_Return  :Bars   [index]   (BNH Cumulative Return)

# %%
plot_algo_vs_bnh_return(tester_30_60_full, '(Segment: 30-60% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Cumulative_Return :Bars   [index]   (Algo Cumulative Return)
#    .Bars.BNH_Cumulative_Return  :Bars   [index]   (BNH Cumulative Return)

# %%
plot_algo_vs_bnh_return(tester_bottom_30_percent_full, '(Segment: Bottom 30% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Cumulative_Return :Bars   [index]   (Algo Cumulative Return)
#    .Bars.BNH_Cumulative_Return  :Bars   [index]   (BNH Cumulative Return)

# %%
plot_algo_vs_bnh_return(tester_top_60_percent_full, '(Segment: Top 60% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Cumulative_Return :Bars   [index]   (Algo Cumulative Return)
#    .Bars.BNH_Cumulative_Return  :Bars   [index]   (BNH Cumulative Return)

# %%
rows = []
sources = [tester_no_seg_full,tester_top_30_percent_full, tester_30_60_full, tester_bottom_30_percent_full, tester_top_60_percent_full]

for i, source in enumerate(sources):
    row = {
        'Best Algo Return Mean': source.groupby('Ticker')['Algo Cumulative Return'].max().median(),
        'BNH Return Mean': source.groupby('Ticker')['BNH Cumulative Return'].mean().median()
    }
    rows.append(row)

new_index = ['No Segmentation' , 'Top 30% Sharpe', 'Top 30-60% Sharpe', 'Bottom 30% Sharpe', 'Top 60% Sharpe']
df = pd.DataFrame(rows, index=new_index)

df.hvplot.bar(width = 1500,
             height = 700,
             color = ['white', 'black'],
             rot = 45,
             hover_color = 'magenta',
             title = 'Median Best Algo Return vs Mean Buy and Hold Return')
# Out:
# :Bars   [index,Variable]   (value)

# %% [markdown]
# ## Algo vs Buy and Hold Sharpe Ratios

# %%
plot_algo_vs_bnh_sharpe(tester_no_seg_full, '(No Segmentation)')
# Out:
# :Overlay
#    .Bars.Algo_Sharpe_Ratio :Bars   [index]   (Algo Sharpe Ratio)
#    .Bars.BNH_Sharpe        :Bars   [index]   (BNH Sharpe)

# %%
plot_algo_vs_bnh_sharpe(tester_top_30_percent_full, '(Segment: Top 30% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Sharpe_Ratio :Bars   [index]   (Algo Sharpe Ratio)
#    .Bars.BNH_Sharpe        :Bars   [index]   (BNH Sharpe)

# %%
plot_algo_vs_bnh_sharpe(tester_30_60_full, '(Segment: 30-60% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Sharpe_Ratio :Bars   [index]   (Algo Sharpe Ratio)
#    .Bars.BNH_Sharpe        :Bars   [index]   (BNH Sharpe)

# %%
plot_algo_vs_bnh_sharpe(tester_bottom_30_percent_full, '(Segment: Bottom 30% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Sharpe_Ratio :Bars   [index]   (Algo Sharpe Ratio)
#    .Bars.BNH_Sharpe        :Bars   [index]   (BNH Sharpe)

# %%
plot_algo_vs_bnh_sharpe(tester_top_60_percent_full, '(Segment: Top 60% Sharpe)')
# Out:
# :Overlay
#    .Bars.Algo_Sharpe_Ratio :Bars   [index]   (Algo Sharpe Ratio)
#    .Bars.BNH_Sharpe        :Bars   [index]   (BNH Sharpe)

# %%
rows = []
sources = [tester_no_seg_full,tester_top_30_percent_full, tester_30_60_full, tester_bottom_30_percent_full, tester_top_60_percent_full]

for i, source in enumerate(sources):
    row = {
        'Best Algo Sharpe Mean': source.groupby('Ticker')['Algo Sharpe Ratio'].max().median(),
        'BNH Sharpe Mean': source.groupby('Ticker')['BNH Sharpe'].mean().median()
    }
    rows.append(row)

new_index = ['No Segmentation','Top 30% Sharpe', 'Top 30-60% Sharpe', 'Bottom 30% Sharpe', 'Top 60% Sharpe']
df = pd.DataFrame(rows, index=new_index)

df.hvplot.bar(width = 1500,
             height = 700,
             color = ['white', 'black'],
             rot = 45,
             hover_color = 'magenta',
             title = 'Median Best Algo Sharpe vs Mean Buy and Hold Sharpe')
# Out:
# :Bars   [index,Variable]   (value)

# %% [markdown]
# # Count of Best Performing Indicators

# %%
signals = []
for s in sources:
    
    s = s.reset_index(drop=True)
    top_strategy_indexes = s.groupby('Ticker')['Algo Cumulative Return'].idxmax()
    
    s =  s.loc[top_strategy_indexes]
    
    vals = s['Buy Signals'].values
    vals = [item[1:-1].replace("'", "").split(", ") for item in vals ]
    for item in vals:
        item.remove('Segmentation_Signal')
        
    signals.append(vals)

def count_unique_items(nested_list):
    flattened_list = [item for sublist1 in nested_list for sublist2 in sublist1 for item in sublist2]
    counts = CounterClass(flattened_list)
    return pd.DataFrame({'Item': counts.keys(), 'Count': counts.values()})

unique_counts_df = count_unique_items(signals).set_index('Item')
swapped_df = unique_counts_df.transpose()

swapped_df.hvplot.bar(cmap = 'gray',
                     width = 1500,
                     height = 500,
                     title = 'Highest-Performing Buy indicators Judging by Returns (Number of Occurences)')
# Out:
# :Bars   [index,Item]   (value)

# %%
signals = []
for s in sources:
    
    s = s.reset_index(drop=True)
    top_strategy_indexes = s.groupby('Ticker')['Algo Cumulative Return'].idxmax()
    
    s =  s.loc[top_strategy_indexes]
    
    vals = s['Sell Signals'].values
    vals = [item[1:-1].replace("'", "").split(", ") for item in vals ]
        
    signals.append(vals)

def count_unique_items(nested_list):
    flattened_list = [item for sublist1 in nested_list for sublist2 in sublist1 for item in sublist2]
    counts = CounterClass(flattened_list)
    return pd.DataFrame({'Item': counts.keys(), 'Count': counts.values()})

unique_counts_df = count_unique_items(signals).set_index('Item')
swapped_df = unique_counts_df.transpose()

swapped_df.hvplot.bar(cmap = 'gray',
                     width = 1500,
                     height = 500,
                     title = 'Highest-Performing Sell Indicators Judging by Returns (Number of Occurences)')
# Out:
# :Bars   [index,Item]   (value)

# %%
signals = []
for s in sources:
    
    s = s.reset_index(drop=True)
    top_strategy_indexes = s.groupby('Ticker')['Algo Sharpe Ratio'].idxmax()
    
    s =  s.loc[top_strategy_indexes]
    
    vals = s['Buy Signals'].values
    vals = [item[1:-1].replace("'", "").split(", ") for item in vals ]
    for item in vals:
        item.remove('Segmentation_Signal')
        
    signals.append(vals)

def count_unique_items(nested_list):
    flattened_list = [item for sublist1 in nested_list for sublist2 in sublist1 for item in sublist2]
    counts = CounterClass(flattened_list)
    return pd.DataFrame({'Item': counts.keys(), 'Count': counts.values()})

unique_counts_df = count_unique_items(signals).set_index('Item')
swapped_df = unique_counts_df.transpose()

swapped_df.hvplot.bar(cmap = 'gray',
                     width = 1500,
                     height = 500,
                     title = 'Highest-Performing Buy Indicators Judging by Sharpe Ratio (Number of Occurences)')
# Out:
# :Bars   [index,Item]   (value)

# %%
signals = []
for s in sources:
    
    s = s.reset_index(drop=True)
    top_strategy_indexes = s.groupby('Ticker')['Algo Sharpe Ratio'].idxmax()
    
    s =  s.loc[top_strategy_indexes]
    
    vals = s['Sell Signals'].values
    vals = [item[1:-1].replace("'", "").split(", ") for item in vals ]
        
    signals.append(vals)

def count_unique_items(nested_list):
    flattened_list = [item for sublist1 in nested_list for sublist2 in sublist1 for item in sublist2]
    counts = CounterClass(flattened_list)
    return pd.DataFrame({'Item': counts.keys(), 'Count': counts.values()})

unique_counts_df = count_unique_items(signals).set_index('Item')
swapped_df = unique_counts_df.transpose()

swapped_df.hvplot.bar(cmap = 'gray',
                     width = 1500,
                     height = 500,
                     title = 'Highest-Performing Sell Indicators Judging by Sharpe Ratio (Number of Occurences)')
# Out:
# :Bars   [index,Item]   (value)

# %%
# So Counter function Overrides list... which is used in the iterator and everywhere else... this will clear it from any values and resolve the 'list' error, run as needed
del list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[775], line 2
#       1 # So Counter function Overrides list... which is used in the iterator and everywhere else... this will clear it from any values and resolve the 'list' error, run as needed
# ----> 2 del list
#
# NameError: name 'list' is not defined

# %%
tester_no_seg_full["Beat BNH"] = np.where(tester_no_seg_full['Algo Cumulative Return'] > tester_no_seg_full['BNH Cumulative Return'], True, False)
tester_top_30_percent_full["Beat BNH"] = np.where(tester_top_30_percent_full['Algo Cumulative Return'] > tester_top_30_percent_full['BNH Cumulative Return'], True, False)
tester_30_60_full["Beat BNH"] = np.where(tester_30_60_full['Algo Cumulative Return'] > tester_30_60_full['BNH Cumulative Return'], True, False)
tester_bottom_30_percent_full["Beat BNH"] = np.where(tester_bottom_30_percent_full['Algo Cumulative Return'] > tester_bottom_30_percent_full['BNH Cumulative Return'], True, False)
tester_top_60_percent_full["Beat BNH"] = np.where(tester_top_60_percent_full['Algo Cumulative Return'] > tester_top_60_percent_full['BNH Cumulative Return'], True, False)

# %% [markdown]
# # How many stocks had an algo that beat buy and hold? By segment

# %%
def percent_of_algos_that_beat_bnh(df):
    
    row_count = df.groupby('Ticker').mean().shape[0]
    df = df.reset_index(drop=True)
    top_strategy_indexes = df.groupby('Ticker')['Algo Cumulative Return'].idxmax()
    df = df.loc[top_strategy_indexes]
    row_count_beat = df[df['Beat BNH'] == True].shape[0]
    
    percent_beat = round(row_count_beat/row_count * 100, 2)
    
    print(f'{percent_beat}% of stocks had an algo that beat bnh')
    
    return df[df['Beat BNH'] == True].sort_values('Algo Sharpe Ratio', ascending= False)

# %% [markdown]
# # No segmentation

# %%
percent_of_algos_that_beat_bnh(tester_no_seg_full)
# Out:
# 62.11% of stocks had an algo that beat bnh
#                                                                                Buy Signals  \
# 25                                     ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 20                                                   ['MFI_Signal', 'Segmentation_Signal']
# 72                 ['EMA50_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 55                                                  ['MACD_Signal', 'Segmentation_Signal']
# 57                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 61                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 49                                  ['EMA20_Signal', 'MACD_Signal', 'Segmentation_Signal']
# 65                                   ['EMA50_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 87                                  ['EMA20_Signal', 'MACD_Signal', 'Segmentation_Signal']
# 82                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 37                  ['EMA50_Signal', 'EMA20_Signal', 'MACD_Signal', 'Segmentation_Signal']
# 39                                                 ['EMA20_Signal', 'Segmentation_Signal']
# 27                                   ['EMA50_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 32                                 ['SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 74               ['EMA50_Signal', 'EMA20_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 94                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 7                                                  ['EMA20_Signal', 'Segmentation_Signal']
# 17                                     ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 81                                   ['EMA50_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 58                                 ['CHAIKIN_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 76                 ['EMA50_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 70                                                  ['MACD_Signal', 'Segmentation_Signal']
# 13                ['EMA20_Signal', 'MACD_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 8                                                ['CHAIKIN_Signal', 'Segmentation_Signal']
# 22                                    ['MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 91                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 79                                    ['MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 90                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 83                                     ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 85                                     ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 68                                                  ['MACD_Signal', 'Segmentation_Signal']
# 46                                   ['EMA20_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 21                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 31                                 ['CHAIKIN_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 53                      ['MACD_Signal', 'SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 10                                                  ['MACD_Signal', 'Segmentation_Signal']
# 36                                                  ['MACD_Signal', 'Segmentation_Signal']
# 14                                                 ['EMA20_Signal', 'Segmentation_Signal']
# 54                                                 ['EMA20_Signal', 'Segmentation_Signal']
# 41                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 34                                     ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 28                ['EMA20_Signal', 'MACD_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 92                                                  ['MACD_Signal', 'Segmentation_Signal']
# 78                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 80  ['EMA50_Signal', 'MACD_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 19                                 ['CHAIKIN_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 18    ['EMA50_Signal', 'EMA20_Signal', 'MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 30                                               ['CHAIKIN_Signal', 'Segmentation_Signal']
# 47                      ['MACD_Signal', 'SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 52                   ['EMA50_Signal', 'EMA20_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 93                                                 ['EMA20_Signal', 'Segmentation_Signal']
# 42                                    ['MACD_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 38                                 ['CHAIKIN_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 35                                   ['EMA50_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 0                     ['EMA20_Signal', 'MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 23                                                   ['MFI_Signal', 'Segmentation_Signal']
# 50                                                 ['EMA50_Signal', 'Segmentation_Signal']
# 88                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 89                                 ['SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
#
#                                         Sell Signals  Algo Annualized Return  \
# 25                                ['BB_Sell_Signal']                0.212873
# 20                  ['BB_Sell_Signal', 'ADX_Signal']                0.090381
# 72                 ['BB_Sell_Signal', 'MACD_Signal']                0.613530
# 55                                   ['MACD_Signal']                0.331991
# 57                ['BB_Sell_Signal', 'EMA20_Signal']                0.630338
# 61                                ['BB_Sell_Signal']                0.318354
# 49                 ['BB_Sell_Signal', 'MACD_Signal']                1.179835
# 65                  ['BB_Sell_Signal', 'ADX_Signal']                0.155674
# 87                 ['BB_Sell_Signal', 'MACD_Signal']                0.269981
# 82                                  ['EMA20_Signal']                0.361845
# 37                                   ['MACD_Signal']                0.207472
# 39                   ['EMA20_Signal', 'MACD_Signal']                0.274748
# 27                                ['BB_Sell_Signal']                0.102776
# 32                                   ['MACD_Signal']                0.318980
# 74                                  ['EMA20_Signal']                0.204939
# 94  ['BB_Sell_Signal', 'EMA20_Signal', 'ADX_Signal']                0.224378
# 7                                    ['MACD_Signal']                0.137121
# 17                                   ['MACD_Signal']                0.100784
# 81                    ['EMA20_Signal', 'ADX_Signal']                0.202908
# 58                                ['BB_Sell_Signal']                0.092228
# 76                                  ['EMA20_Signal']                0.401668
# 70                                   ['MACD_Signal']                0.139178
# 13                 ['BB_Sell_Signal', 'MACD_Signal']                0.210824
# 8                                    ['MACD_Signal']                0.136968
# 22                                   ['MACD_Signal']                0.250200
# 91                                ['BB_Sell_Signal']                0.179450
# 79                                   ['MACD_Signal']                0.247238
# 90                                   ['MACD_Signal']                0.142435
# 83                  ['BB_Sell_Signal', 'ADX_Signal']                0.060505
# 85                                ['BB_Sell_Signal']                0.168892
# 68                     ['MACD_Signal', 'ADX_Signal']                0.196534
# 46                   ['EMA20_Signal', 'MACD_Signal']                0.147383
# 21                                ['BB_Sell_Signal']                0.231046
# 31                                ['BB_Sell_Signal']                0.080947
# 53                                   ['MACD_Signal']                0.041196
# 10                 ['BB_Sell_Signal', 'MACD_Signal']                0.313682
# 36                ['BB_Sell_Signal', 'EMA20_Signal']                0.157828
# 14                ['BB_Sell_Signal', 'EMA20_Signal']                0.134118
# 54                   ['EMA20_Signal', 'MACD_Signal']                0.087612
# 41                                ['BB_Sell_Signal']                0.233630
# 34                                ['BB_Sell_Signal']                0.286346
# 28                                   ['MACD_Signal']                0.150953
# 92                                   ['MACD_Signal']                0.144768
# 78                                ['BB_Sell_Signal']                0.172800
# 80                    ['EMA20_Signal', 'ADX_Signal']                0.140911
# 19                                ['BB_Sell_Signal']                0.081038
# 18                                   ['MACD_Signal']                0.087029
# 30   ['BB_Sell_Signal', 'MACD_Signal', 'ADX_Signal']                0.068360
# 47                                ['BB_Sell_Signal']                0.097223
# 52                                ['BB_Sell_Signal']                0.225318
# 93                                  ['EMA20_Signal']                0.191198
# 42                                ['BB_Sell_Signal']                0.054395
# 38                                    ['ADX_Signal']                0.021758
# 35                  ['BB_Sell_Signal', 'ADX_Signal']                0.016518
# 0                                    ['MACD_Signal']                0.135400
# 23                                ['BB_Sell_Signal']                0.130110
# 50                                ['BB_Sell_Signal']                0.078648
# 88                                  ['EMA20_Signal']                0.032479
# 89                  ['BB_Sell_Signal', 'ADX_Signal']                0.013864
#
#     Algo Cumulative Return  Algo Annual Volatility  Algo Sharpe Ratio  \
# 25                3.608412                0.162028           1.313805
# 20                1.757742                0.072148           1.252726
# 72               22.797851                0.532946           1.151204
# 55                6.401009                0.295695           1.122745
# 57                8.422009                0.563591           1.118431
# 61                5.902655                0.289452           1.099849
# 49               74.770001                1.073276           1.099284
# 65                2.544912                0.145473           1.070125
# 87                4.550056                0.262589           1.028151
# 82                6.566382                0.370872           0.975661
# 37                3.277914                0.214113           0.968981
# 39                4.517676                0.284643           0.965236
# 27                1.865952                0.106628           0.963878
# 32                5.441262                0.333723           0.955824
# 74                3.173247                0.225114           0.910376
# 94                2.236845                0.247829           0.905375
# 7                 2.241986                0.151473           0.905254
# 17                1.474420                0.112199           0.898258
# 81                2.508374                0.227862           0.890488
# 58                1.744203                0.107952           0.854343
# 76                5.320689                0.470761           0.853231
# 70                2.243640                0.164107           0.848094
# 13                3.137700                0.257052           0.820161
# 8                 2.201290                0.168656           0.812113
# 22                3.693599                0.308138           0.811976
# 91                2.704394                0.221822           0.808981
# 79                3.582658                0.313804           0.787873
# 90                2.252855                0.181299           0.785634
# 83                1.446418                0.078414           0.771614
# 85                2.529348                0.221475           0.762578
# 68                2.860237                0.260887           0.753332
# 46                2.277090                0.196250           0.750996
# 21                3.201902                0.315216           0.732978
# 31                1.617121                0.111506           0.725939
# 53                1.289022                0.058265           0.707048
# 10                4.023597                0.446375           0.702731
# 36                2.338377                0.227152           0.694811
# 14                2.084705                0.199412           0.672566
# 54                1.657509                0.133477           0.656388
# 41                2.966678                0.357118           0.654210
# 34                3.391383                0.439857           0.650998
# 28                2.173108                0.246331           0.612805
# 92                2.120272                0.236624           0.611808
# 78                2.338107                0.284905           0.606519
# 80                2.018806                0.244113           0.577236
# 19                1.574624                0.143965           0.562897
# 18                1.607182                0.162028           0.537122
# 30                1.468501                0.132076           0.517584
# 47                1.649045                0.196005           0.496024
# 52                1.887517                0.500165           0.450487
# 93                1.906182                0.428069           0.446654
# 42                1.333627                0.139260           0.390603
# 38                1.138680                0.055975           0.388704
# 35                1.105210                0.043715           0.377849
# 0                 1.598188                0.361638           0.374408
# 23                1.558262                0.348515           0.373326
# 50                1.362444                0.246673           0.318833
# 88                1.174677                0.121945           0.266343
# 89                0.992062                0.173883           0.079734
#
#     BNH Cumulative Return  BNH Volatility  BNH Sharpe Ticker  Beat BNH
# 25               2.384893        0.288767    0.613658    CSX      True
# 20               1.579774        0.313585    0.386645    CAH      True
# 72              12.152174        0.850260    0.856417   PLUG      True
# 55               3.141250        0.438516    0.628196    MPC      True
# 57               7.478873        0.768020    0.960857   MRNA      True
# 61               5.740471        0.290397    1.082869   MSFT      True
# 49               0.643121        1.667784    0.656787   MARA      True
# 65               2.178814        0.314818    0.541895    NKE      True
# 87               2.353144        0.440886    0.520715    VLO      True
# 82               4.951253        0.610042    0.715121     SQ      True
# 37               1.291279        0.390158    0.297013     GM      True
# 39               0.749766        0.514409    0.177577    HAL      True
# 27               1.858484        0.325781    0.460552    CVX      True
# 32               1.435192        0.557228    0.384768    DVN      True
# 74               1.784234        0.404640    0.427103   PYPL      True
# 94               0.823668        0.640316    0.240281     ZM      True
# 7                1.702344        0.243323    0.461723   AMGN      True
# 17               0.160774        0.832468   -0.129114   BYND      True
# 81               0.944588        0.494805    0.224871   SPOT      True
# 58               1.587186        0.558864    0.419800    MRO      True
# 76               4.014369        0.794441    0.693628   ROKU      True
# 70               1.506353        0.242632    0.383983    PFE      True
# 13               1.454151        0.460076    0.357031     BA      True
# 8                2.148244        0.269737    0.576337    AMT      True
# 22               3.071125        0.457245    0.609629    CCJ      True
# 91               2.626893        0.222364    0.787603    WMT      True
# 79               0.825006        0.451086    0.161260    SLB      True
# 90               1.608401        0.365288    0.386196   WELL      True
# 83               0.813787        0.246241   -0.006622      T      True
# 85               2.289779        0.274123    0.607334   TMUS      True
# 68               1.083948        0.566667    0.321582    OXY      True
# 46               0.780868        0.366124    0.078002    LUV      True
# 21               3.149339        0.315486    0.724798    CAT      True
# 31               0.118290        0.481712   -0.447003   DISH      True
# 53               0.729210        0.258035   -0.060850    MMM      True
# 10               0.715358        0.653942    0.267981    APA      True
# 36               0.675533        0.399262    0.046588     GE      True
# 14               1.468284        0.332257    0.345669    BAC      True
# 54               0.986297        0.248503    0.116696     MO      True
# 41               2.682156        0.358159    0.609780    HPQ      True
# 34               2.513559        0.505397    0.536024    FCX      True
# 28               1.111600        0.437309    0.258237    DAL      True
# 92               2.085644        0.350161    0.501186    WPM      True
# 78               2.116312        0.287588    0.549956   SBUX      True
# 80               0.565468        0.759370    0.259881   SNAP      True
# 19               1.017610        0.273497    0.147643    CAG      True
# 18               1.006416        0.356885    0.181687      C      True
# 30               0.844864        0.304437    0.065488    DIS      True
# 47               0.715765        0.607097    0.215596      M      True
# 52               1.713850        0.501652    0.420798    MGM      True
# 93               0.741735        0.593794    0.219634      X      True
# 42               1.089822        0.359554    0.217957   INTC      True
# 38               1.004659        0.351206    0.176944   GOLD      True
# 35               0.978560        0.438519    0.213332   GDXJ      True
# 0                0.442058        0.565868    0.051630    AAL      True
# 23               1.460799        0.399197    0.348703    COF      True
# 50               1.337943        0.246988    0.307418    MDT      True
# 88               0.992904        0.194855    0.091645     VZ      True
# 89               0.476737        0.312243   -0.212383    WBA      True

# %%
strategy = BespokeStrategy('CSX', '1d', stocks_1d, buy_signals= ['SQZ_Signal', 'MFI_Signal'], sell_signals= ['BB_Sell_Signal'], lower_segment_boundary = 100, upper_segment_boundary= 0)
strategy.result()
strategy.plot_strategy()
strategy.stats()
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2017-02-02
# End Period          2023-07-11
# Risk-Free Rate      0.0%
# Time in Market      44.0%
#
# Cumulative Return   260.84%
# CAGR﹪              14.75%
#
# Sharpe              1.31
# Prob. Sharpe Ratio  99.97%
# Sortino             2.13
# Sortino/√2          1.5
# Omega               1.39
#
# Max Drawdown        -13.93%
# Longest DD Days     175
#
# Gain/Pain Ratio     0.39
# Gain/Pain (1M)      4.31
#
# Payoff Ratio        1.22
# Profit Factor       1.39
# Common Sense Ratio  1.69
# CPC Index           0.9
# Tail Ratio          1.21
# Outlier Win Ratio   8.74
# Outlier Loss Ratio  2.65
#
# MTD                 -0.97%
# 3M                  13.01%
# 6M                  4.98%
# YTD                 9.79%
# 1Y                  36.92%
# 3Y (ann.)           20.21%
# 5Y (ann.)           18.04%
# 10Y (ann.)          14.75%
# All-time (ann.)     14.75%
#
# Avg. Drawdown       -3.13%
# Avg. Drawdown Days  15
# Recovery Factor     9.82
# Ulcer Index         0.03
# Serenity Index      9.84
# <h4>Strategy Visualization</h4>

# %% [markdown]
# # Top 30% Sharpe

# %%
percent_of_algos_that_beat_bnh(tester_top_30_percent_full)
# Out:
# 71.58% of stocks had an algo that beat bnh
#                                                                                     Buy Signals  \
# 37800  ['EMA50_Signal', 'EMA20_Signal', 'MACD_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 12285                                                    ['MACD_Signal', 'Segmentation_Signal']
# 6615                                                      ['SQZ_Signal', 'Segmentation_Signal']
# 51975                                    ['EMA20_Signal', 'MACD_Signal', 'Segmentation_Signal']
# 82215                                                    ['MACD_Signal', 'Segmentation_Signal']
# ...                                                                                         ...
# 17010                      ['EMA50_Signal', 'MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 50085                    ['MACD_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 78435                      ['EMA20_Signal', 'MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 29295                      ['EMA20_Signal', 'MACD_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 84105                      ['EMA20_Signal', 'MACD_Signal', 'MFI_Signal', 'Segmentation_Signal']
#
#                                             Sell Signals  \
# 37800                                    ['MACD_Signal']
# 12285                                    ['MACD_Signal']
# 6615                                     ['MACD_Signal']
# 51975                                   ['EMA20_Signal']
# 82215                                    ['MACD_Signal']
# ...                                                  ...
# 17010                  ['BB_Sell_Signal', 'MACD_Signal']
# 50085                  ['BB_Sell_Signal', 'MACD_Signal']
# 78435  ['BB_Sell_Signal', 'EMA20_Signal', 'MACD_Signal']
# 29295                      ['MACD_Signal', 'ADX_Signal']
# 84105                      ['MACD_Signal', 'ADX_Signal']
#
#        Algo Annualized Return  Algo Cumulative Return  Algo Annual Volatility  \
# 37800                0.162310                2.739826                0.103929
# 12285                0.257418                4.509045                0.215196
# 6615                 0.151982                2.515408                0.129762
# 51975                0.279436                5.000007                0.242530
# 82215                0.247968                4.233749                0.216980
# ...                       ...                     ...                     ...
# 17010                0.017766                1.056328                0.135318
# 50085                0.006988                1.012352                0.099831
# 78435                0.007081                1.009824                0.104847
# 29295                0.000000                1.000000                0.000000
# 84105                0.000000                1.000000                0.000000
#
#        Algo Sharpe Ratio  BNH Cumulative Return  BNH Volatility  BNH Sharpe  \
# 37800           1.561745               2.674927        0.267335    0.708886
# 12285           1.196200               1.454151        0.460076    0.357031
# 6615            1.171238               1.702344        0.243323    0.461723
# 51975           1.152171               3.141250        0.438516    0.628196
# 82215           1.142814               2.353144        0.440886    0.520715
# ...                  ...                    ...             ...         ...
# 17010           0.131289               1.006416        0.356885    0.181687
# 50085           0.069998               0.729210        0.258035   -0.060850
# 78435           0.067536               0.813787        0.246241   -0.006622
# 29295                NaN               0.118290        0.481712   -0.447003
# 84105                NaN               0.476737        0.312243   -0.212383
#
#       Ticker  Beat BNH
# 37800     HD      True
# 12285     BA      True
# 6615    AMGN      True
# 51975    MPC      True
# 82215    VLO      True
# ...      ...       ...
# 17010      C      True
# 50085    MMM      True
# 78435      T      True
# 29295   DISH      True
# 84105    WBA      True
#
# [68 rows x 11 columns]

# %%
strategy = BespokeStrategy('HD', '1d', stocks_1d, buy_signals= ['EMA50_Signal', 'EMA20_Signal', 'MACD_Signal', 'CHAIKIN_Signal'], sell_signals= ['MACD_Signal'], lower_segment_boundary = 31, upper_segment_boundary= 0)
strategy.result()
strategy.plot_strategy()
strategy.stats()
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2017-02-02
# End Period          2023-07-11
# Risk-Free Rate      0.0%
# Time in Market      33.0%
#
# Cumulative Return   173.98%
# CAGR﹪              11.41%
#
# Sharpe              1.56
# Prob. Sharpe Ratio  100.0%
# Sortino             2.55
# Sortino/√2          1.8
# Omega               1.57
#
# Max Drawdown        -9.82%
# Longest DD Days     329
#
# Gain/Pain Ratio     0.57
# Gain/Pain (1M)      4.65
#
# Payoff Ratio        1.21
# Profit Factor       1.57
# Common Sense Ratio  2.37
# CPC Index           1.08
# Tail Ratio          1.51
# Outlier Win Ratio   11.39
# Outlier Loss Ratio  2.69
#
# MTD                 -2.77%
# 3M                  -2.22%
# 6M                  -2.22%
# YTD                 -2.22%
# 1Y                  2.83%
# 3Y (ann.)           5.18%
# 5Y (ann.)           11.03%
# 10Y (ann.)          11.41%
# All-time (ann.)     11.41%
#
# Avg. Drawdown       -1.68%
# Avg. Drawdown Days  30
# Recovery Factor     10.62
# Ulcer Index         0.03
# Serenity Index      3.61
# <h4>Strategy Visualization</h4>

# %% [markdown]
# # Middle 30-60% Sharpe

# %%
percent_of_algos_that_beat_bnh(tester_30_60_full)
# Out:
# 70.53% of stocks had an algo that beat bnh
#                                                                                   Buy Signals  \
# 77490                               ['EMA50_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 68040                                 ['SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 57645                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 46305                                   ['EMA20_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 36855                                  ['EMA20_Signal', 'MACD_Signal', 'Segmentation_Signal']
# ...                                                                                       ...
# 84105                  ['MACD_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 33075                                                   ['SQZ_Signal', 'Segmentation_Signal']
# 39690                                                   ['MFI_Signal', 'Segmentation_Signal']
# 29295  ['EMA20_Signal', 'MACD_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 83160                                                   ['SQZ_Signal', 'Segmentation_Signal']
#
#                                         Sell Signals  Algo Annualized Return  \
# 77490             ['BB_Sell_Signal', 'EMA20_Signal']                0.390758
# 68040                             ['BB_Sell_Signal']                0.881216
# 57645                             ['BB_Sell_Signal']                0.314770
# 46305             ['BB_Sell_Signal', 'EMA20_Signal']                0.857300
# 36855                                ['MACD_Signal']                0.277304
# ...                                              ...                     ...
# 84105               ['BB_Sell_Signal', 'ADX_Signal']                0.032433
# 33075               ['BB_Sell_Signal', 'ADX_Signal']                0.070378
# 39690                                 ['ADX_Signal']                0.032074
# 29295  ['EMA20_Signal', 'MACD_Signal', 'ADX_Signal']                0.014524
# 83160              ['BB_Sell_Signal', 'MACD_Signal']                0.014303
#
#        Algo Cumulative Return  Algo Annual Volatility  Algo Sharpe Ratio  \
# 77490                8.825057                0.321280           1.216253
# 68040               53.742188                0.749064           1.176423
# 57645                5.792627                0.287194           1.096017
# 46305               31.433222                0.837963           1.023076
# 36855                4.697705                0.272036           1.019364
# ...                       ...                     ...                ...
# 84105                1.165395                0.131549           0.246549
# 33075                1.208197                0.286954           0.245259
# 39690                1.163917                0.130903           0.245023
# 29295                1.082003                0.067397           0.215503
# 83160                1.062598                0.098489           0.145225
#
#        BNH Cumulative Return  BNH Volatility  BNH Sharpe Ticker  Beat BNH
# 77490               4.951253        0.610042    0.715121     SQ      True
# 68040              12.152174        0.850260    0.856417   PLUG      True
# 57645               5.740471        0.290397    1.082869   MSFT      True
# 46305               0.643121        1.667784    0.656787   MARA      True
# 36855               0.749766        0.514409    0.177577    HAL      True
# ...                      ...             ...         ...    ...       ...
# 84105               0.476737        0.312243   -0.212383    WBA      True
# 33075               0.978560        0.438519    0.213332   GDXJ      True
# 39690               1.089822        0.359554    0.217957   INTC      True
# 29295               0.118290        0.481712   -0.447003   DISH      True
# 83160               0.992904        0.194855    0.091645     VZ      True
#
# [67 rows x 11 columns]

# %%
strategy = BespokeStrategy('SQ', '1d', stocks_1d, buy_signals= ['EMA50_Signal', 'CHAIKIN_Signal'], sell_signals= ['BB_Sell_Signal', 'EMA20_Signal'], lower_segment_boundary = 62, upper_segment_boundary= 31)
strategy.result()
strategy.plot_strategy()
strategy.stats()
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2017-02-02
# End Period          2023-07-11
# Risk-Free Rate      0.0%
# Time in Market      41.0%
#
# Cumulative Return   782.51%
# CAGR﹪              26.3%
#
# Sharpe              1.22
# Prob. Sharpe Ratio  99.89%
# Sortino             1.85
# Sortino/√2          1.31
# Omega               1.39
#
# Max Drawdown        -29.15%
# Longest DD Days     710
#
# Gain/Pain Ratio     0.39
# Gain/Pain (1M)      1.96
#
# Payoff Ratio        1.06
# Profit Factor       1.39
# Common Sense Ratio  1.57
# CPC Index           0.84
# Tail Ratio          1.13
# Outlier Win Ratio   9.97
# Outlier Loss Ratio  2.67
#
# MTD                 2.58%
# 3M                  4.3%
# 6M                  -0.9%
# YTD                 7.37%
# 1Y                  2.23%
# 3Y (ann.)           6.22%
# 5Y (ann.)           17.22%
# 10Y (ann.)          26.3%
# All-time (ann.)     26.3%
#
# Avg. Drawdown       -6.7%
# Avg. Drawdown Days  51
# Recovery Factor     8.61
# Ulcer Index         0.16
# Serenity Index      1.24
# <h4>Strategy Visualization</h4>

# %% [markdown]
# # Bottom 30% Sharpe

# %%
percent_of_algos_that_beat_bnh(tester_bottom_30_percent_full)
# Out:
# 66.32% of stocks had an algo that beat bnh
#                                                                    Buy Signals  \
# 23625                                    ['MFI_Signal', 'Segmentation_Signal']
# 68040     ['EMA50_Signal', 'MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 30240                                ['CHAIKIN_Signal', 'Segmentation_Signal']
# 66150                                   ['MACD_Signal', 'Segmentation_Signal']
# 69930                  ['EMA50_Signal', 'EMA20_Signal', 'Segmentation_Signal']
# ...                                                                        ...
# 87885                    ['EMA50_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 35910                                    ['MFI_Signal', 'Segmentation_Signal']
# 83160  ['EMA20_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
# 24570                                    ['SQZ_Signal', 'Segmentation_Signal']
# 84105   ['MACD_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
#
#                             Sell Signals  Algo Annualized Return  \
# 23625                 ['BB_Sell_Signal']                0.212873
# 68040                 ['BB_Sell_Signal']                0.648293
# 30240  ['BB_Sell_Signal', 'MACD_Signal']                0.309247
# 66150                    ['MACD_Signal']                0.135650
# 69930                   ['EMA20_Signal']                0.161041
# ...                                  ...                     ...
# 87885                     ['ADX_Signal']                0.030460
# 35910                 ['BB_Sell_Signal']                0.085098
# 83160                    ['MACD_Signal']                0.024778
# 24570                 ['BB_Sell_Signal']                0.075315
# 84105   ['BB_Sell_Signal', 'ADX_Signal']                0.012623
#
#        Algo Cumulative Return  Algo Annual Volatility  Algo Sharpe Ratio  \
# 23625                3.608412                0.162028           1.313805
# 68040               28.150313                0.545758           1.187877
# 30240                5.691309                0.279917           1.104779
# 66150                2.272082                0.126375           1.073394
# 69930                2.611986                0.152824           1.053768
# ...                       ...                     ...                ...
# 87885                1.191798                0.081375           0.374314
# 35910                1.378558                0.265460           0.320568
# 83160                1.149554                0.078649           0.315051
# 24570                1.311453                0.256907           0.293162
# 84105                1.063902                0.077382           0.163120
#
#        BNH Cumulative Return  BNH Volatility  BNH Sharpe Ticker  Beat BNH
# 23625               2.384893        0.288767    0.613658    CSX      True
# 68040              12.152174        0.850260    0.856417   PLUG      True
# 30240               1.435192        0.557228    0.384768    DVN      True
# 66150               1.506353        0.242632    0.383983    PFE      True
# 69930               1.784234        0.404640    0.427103   PYPL      True
# ...                      ...             ...         ...    ...       ...
# 87885               0.741735        0.593794    0.219634      X      True
# 35910               1.004659        0.351206    0.176944   GOLD      True
# 83160               0.992904        0.194855    0.091645     VZ      True
# 24570               1.135070        0.276941    0.210369    CVS      True
# 84105               0.476737        0.312243   -0.212383    WBA      True
#
# [63 rows x 11 columns]

# %%
strategy = BespokeStrategy('CSX', '1d', stocks_1d, buy_signals= ['MFI_Signal'], sell_signals= ['BB_Sell_Signal'], lower_segment_boundary = 100, upper_segment_boundary= 62)
strategy.result()
strategy.plot_strategy()
strategy.stats()
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2017-02-02
# End Period          2023-07-11
# Risk-Free Rate      0.0%
# Time in Market      44.0%
#
# Cumulative Return   260.84%
# CAGR﹪              14.75%
#
# Sharpe              1.31
# Prob. Sharpe Ratio  99.97%
# Sortino             2.13
# Sortino/√2          1.5
# Omega               1.39
#
# Max Drawdown        -13.93%
# Longest DD Days     175
#
# Gain/Pain Ratio     0.39
# Gain/Pain (1M)      4.31
#
# Payoff Ratio        1.22
# Profit Factor       1.39
# Common Sense Ratio  1.69
# CPC Index           0.9
# Tail Ratio          1.21
# Outlier Win Ratio   8.74
# Outlier Loss Ratio  2.65
#
# MTD                 -0.97%
# 3M                  13.01%
# 6M                  4.98%
# YTD                 9.79%
# 1Y                  36.92%
# 3Y (ann.)           20.21%
# 5Y (ann.)           18.04%
# 10Y (ann.)          14.75%
# All-time (ann.)     14.75%
#
# Avg. Drawdown       -3.13%
# Avg. Drawdown Days  15
# Recovery Factor     9.82
# Ulcer Index         0.03
# Serenity Index      9.84
# <h4>Strategy Visualization</h4>

# %% [markdown]
# # Top 60% Sharpe

# %%
percent_of_algos_that_beat_bnh(tester_top_60_percent_full)
# Out:
# 75.79% of stocks had an algo that beat bnh
#                                                                    Buy Signals  \
# 945                                     ['MACD_Signal', 'Segmentation_Signal']
# 81270                                   ['MACD_Signal', 'Segmentation_Signal']
# 82215                                   ['MACD_Signal', 'Segmentation_Signal']
# 68040                     ['MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 51975                                   ['MACD_Signal', 'Segmentation_Signal']
# ...                                                                        ...
# 33075                                    ['SQZ_Signal', 'Segmentation_Signal']
# 39690                      ['SQZ_Signal', 'MFI_Signal', 'Segmentation_Signal']
# 83160                     ['MACD_Signal', 'SQZ_Signal', 'Segmentation_Signal']
# 84105                                    ['SQZ_Signal', 'Segmentation_Signal']
# 29295  ['EMA20_Signal', 'SQZ_Signal', 'CHAIKIN_Signal', 'Segmentation_Signal']
#
#                                            Sell Signals  \
# 945                                     ['MACD_Signal']
# 81270                                   ['MACD_Signal']
# 82215                 ['BB_Sell_Signal', 'MACD_Signal']
# 68040                 ['BB_Sell_Signal', 'MACD_Signal']
# 51975                                   ['MACD_Signal']
# ...                                                 ...
# 33075                  ['BB_Sell_Signal', 'ADX_Signal']
# 39690                  ['BB_Sell_Signal', 'ADX_Signal']
# 83160                   ['EMA20_Signal', 'MACD_Signal']
# 84105                  ['BB_Sell_Signal', 'ADX_Signal']
# 29295  ['BB_Sell_Signal', 'EMA20_Signal', 'ADX_Signal']
#
#        Algo Annualized Return  Algo Cumulative Return  Algo Annual Volatility  \
# 945                  0.310135                6.614869                0.178489
# 81270                0.552706               20.166625                0.414809
# 82215                0.330267                6.526468                0.282216
# 68040                0.660624               25.932351                0.581943
# 51975                0.301668                5.546312                0.266915
# ...                       ...                     ...                     ...
# 33075                0.087275                1.315984                0.299249
# 39690                0.032074                1.163917                0.130903
# 83160                0.013081                1.055791                0.096213
# 84105                0.023904                1.046676                0.183371
# 29295                0.008329                1.005538                0.121851
#
#        Algo Sharpe Ratio  BNH Cumulative Return  BNH Volatility  BNH Sharpe  \
# 945             1.737554               6.272701        0.308233    1.082453
# 81270           1.332435              16.087657        0.616970    1.009526
# 82215           1.170264               2.353144        0.440886    0.520715
# 68040           1.135204              12.152174        0.850260    0.856417
# 51975           1.130203               3.141250        0.438516    0.628196
# ...                  ...                    ...             ...         ...
# 33075           0.291648               0.978560        0.438519    0.213332
# 39690           0.245023               1.089822        0.359554    0.217957
# 83160           0.135961               0.992904        0.194855    0.091645
# 84105           0.130356               0.476737        0.312243   -0.212383
# 29295           0.068351               0.118290        0.481712   -0.447003
#
#       Ticker  Beat BNH
# 945     AAPL      True
# 81270   TSLA      True
# 82215    VLO      True
# 68040   PLUG      True
# 51975    MPC      True
# ...      ...       ...
# 33075   GDXJ      True
# 39690   INTC      True
# 83160     VZ      True
# 84105    WBA      True
# 29295   DISH      True
#
# [72 rows x 11 columns]

# %%
strategy = BespokeStrategy('AAPL', '1d', stocks_1d, buy_signals= ['MACD_Signal'], sell_signals= ['MACD_Signal'], lower_segment_boundary = 62, upper_segment_boundary= 0)
strategy.result()
strategy.plot_strategy()
strategy.stats()
# Out:
# <h4>Performance Metrics</h4>
#                     Strategy
# ------------------  ----------
# Start Period        2017-02-02
# End Period          2023-07-11
# Risk-Free Rate      0.0%
# Time in Market      50.0%
#
# Cumulative Return   561.49%
# CAGR﹪              22.46%
#
# Sharpe              1.74
# Prob. Sharpe Ratio  100.0%
# Sortino             2.79
# Sortino/√2          1.97
# Omega               1.56
#
# Max Drawdown        -13.98%
# Longest DD Days     283
#
# Gain/Pain Ratio     0.56
# Gain/Pain (1M)      2.86
#
# Payoff Ratio        1.25
# Profit Factor       1.56
# Common Sense Ratio  2.19
# CPC Index           1.08
# Tail Ratio          1.4
# Outlier Win Ratio   8.03
# Outlier Loss Ratio  3.04
#
# MTD                 -2.76%
# 3M                  1.54%
# 6M                  13.87%
# YTD                 13.87%
# 1Y                  26.48%
# 3Y (ann.)           16.45%
# 5Y (ann.)           24.34%
# 10Y (ann.)          22.46%
# All-time (ann.)     22.46%
#
# Avg. Drawdown       -2.55%
# Avg. Drawdown Days  26
# Recovery Factor     14.26
# Ulcer Index         0.05
# Serenity Index      4.92
# <h4>Strategy Visualization</h4>
