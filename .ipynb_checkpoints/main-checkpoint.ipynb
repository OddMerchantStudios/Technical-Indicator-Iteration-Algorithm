# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import yfinance as yf
import hvplot.pandas
from pathlib import Path
import requests
import json
import csv
import io
from finta import TA
import matplotlib.pyplot as plt
import quantstats as qs
import itertools

# %%
### Quant framework 3 x 3 x 3

#     Intraday   >>Swing<<    >>Position<<

#     Earnings     Event      >>TA<<

#   >>Delta<<      Theta        Vega

# Project 2 scope is focused on Swing and Position timeframe, while relying on TA
# to determine signals. Option strategies are not used.

### Technical goal:

# Automate creation and testing of new trading algorithms based on our framework

### Plan:

# 1. Pull the data: ohlc + volume ✓
# 2. Integrate Finta with our data ✓
# 3. Determine trading signals for testable indicators (crossovers, etc.)✓
# 4. Test the strategy on data of 2017 - 2019 
# 5. Automate testing of different combinations of strategies
# 6. Train ML algorithms on best performing strategies
# 7. Deploy trained ML algorithms and test performance on 2020-2023 data

# %%
sqrt = np.sqrt(252)
alpha_vantage_key = 'N35DJ1POAUO7MXX6'
trading_days_year = 252
total_days_year = 365
thirty_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 30)).date()
ten_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 10)).date()
five_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 5)).date()
three_years_ago = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 3)).date()
one_year = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year * 1)).date()
six_months = (pd.Timestamp.today() - pd.Timedelta(days = total_days_year / 2)).date()
yesterday = (pd.Timestamp.today() - pd.Timedelta(days = 1)).date()

url = f'https://www.alphavantage.co/query?function=LISTING_STATUS&apikey={alpha_vantage_key}'
response = requests.get(url)
data = response.text

# Portfolio vars

share_size = 100
initial_capital = 100000

# %% [markdown]
# # 1. Pull the data: ohlc + volume

# %%
listed_stocks = pd.read_csv(io.StringIO(data))
listed_stocks = listed_stocks[listed_stocks['exchange'] == 'NASDAQ']
listed_stocks = listed_stocks[listed_stocks['symbol'].str.len() <= 4]
listed_stocks = listed_stocks[listed_stocks['ipoDate'] <= '2017-01-01']
listed_stocks
# Out:
#       symbol                                 name exchange assetType  \
# 7       AACG                ATA Creativity Global   NASDAQ     Stock
# 15      AADR  AdvisorShares Dorsey Wright ADR ETF   NASDAQ       ETF
# 20       AAL          American Airlines Group Inc   NASDAQ     Stock
# 22      AAME               Atlantic American Corp   NASDAQ     Stock
# 24      AAOI          Applied Optoelectronics Inc   NASDAQ     Stock
# ...      ...                                  ...      ...       ...
# 11539   ZUMZ                           Zumiez Inc   NASDAQ     Stock
# 11544   ZVRA               Zevra Therapeutics Inc   NASDAQ     Stock
# 11553   ZYNE          Zynerba Pharmaceuticals Inc   NASDAQ     Stock
# 11554   ZYRX          Global Earnings Capital Ltd   NASDAQ     Stock
# 11555   ZYXI                            Zynex Inc   NASDAQ     Stock
#
#           ipoDate  delistingDate  status
# 7      2008-01-29            NaN  Active
# 15     2010-07-21            NaN  Active
# 20     2005-09-27            NaN  Active
# 22     1984-09-07            NaN  Active
# 24     2013-09-26            NaN  Active
# ...           ...            ...     ...
# 11539  2005-05-06            NaN  Active
# 11544  2015-04-16            NaN  Active
# 11553  2015-08-05            NaN  Active
# 11554  2007-07-13            NaN  Active
# 11555  2012-07-23            NaN  Active
#
# [2132 rows x 7 columns]

# %%
symbols = listed_stocks['symbol']
symbols_str = symbols.to_list()
yf_df = yf.Tickers(symbols_str)
df_full =yf_df.history(start = '2017-01-01', end = yesterday)
# Out:
# [*********************100%***********************]  2132 of 2132 completed
# ERROR
# 4 Failed downloads:
# ERROR ['ZYRX']: Exception('ZYRX: No timezone found, symbol may be delisted')
# ERROR ['AGFS']: Exception('AGFS: No data found, symbol may be delisted')
# ERROR ['RNWK']: Exception('RNWK: No timezone found, symbol may be delisted')
# ERROR ['AGTC']: Exception('AGTC: No timezone found, symbol may be delisted')

# %%
stocks = df_full[['Open', 'Close', 'High', 'Low', 'Volume']]
stocks.dropna(inplace= True, axis= 1)
stocks.head()
# Out:
#                          Open                                             \
#                          AACG       AADR        AAL      AAME       AAOI
# Date
# 2017-01-03 00:00:00  0.046274  38.225508  45.688232  3.930859  23.709999
# 2017-01-04 00:00:00  0.047125  39.027700  45.060123  4.027917  23.129999
# 2017-01-05 00:00:00  0.046396  39.634008  44.953827  4.047329  23.500000
# 2017-01-06 00:00:00  0.048339  39.307536  44.306374  3.979388  22.990000
# 2017-01-09 00:00:00  0.044453  39.717959  44.460992  4.076446  22.360001
#
#                                                                          ...  \
#                           AAON       AAPL       AAXJ       ABCB    ABEO  ...
# Date                                                                     ...
# 2017-01-03 00:00:00  32.015934  27.014199  49.426866  40.412979  127.50  ...
# 2017-01-04 00:00:00  32.015923  27.025862  49.694231  40.092600  123.75  ...
# 2017-01-05 00:00:00  32.590205  27.042191  50.425026  40.687579  133.75  ...
# 2017-01-06 00:00:00  31.728794  27.242818  50.425026  40.596046  147.50  ...
# 2017-01-09 00:00:00  31.106657  27.515755  50.362645  39.863771  152.50  ...
#
#                      Volume                                                \
#                          ZD    ZEUS      ZG     ZION   ZIVO  ZTEK    ZUMZ
# Date
# 2017-01-03 00:00:00  353740  148800  640200  2896200  23300  5400  679600
# 2017-01-04 00:00:00  413310  107700  453000  1907500  22600     0  559500
# 2017-01-05 00:00:00  581210  116900  466000  2106000  43000     0  826200
# 2017-01-06 00:00:00  463220  126800  438900  2149100   2000     0  455400
# 2017-01-09 00:00:00  534060  175600  377500  2104900  20000     0  536300
#
#
#                      ZVRA    ZYNE   ZYXI
# Date
# 2017-01-03 00:00:00  6638  409800   2530
# 2017-01-04 00:00:00  8131  578500      0
# 2017-01-05 00:00:00  2606  436300   1650
# 2017-01-06 00:00:00   825  325700  13420
# 2017-01-09 00:00:00  3525  212900  31680
#
# [5 rows x 10255 columns]

# %% [markdown]
# # 2. Integrate Finta with our data

# %%
### List of indicators we will use:

# 1. EMA 8/21
# 2. BBANDS + KELTNER CHANNELS (KC)
# 3. ADX
# 4. MACD
# 6. ICHIMOKU (optional)
# 7. VWAP

# %%
def get_individual_stock(stock, stocks = stocks):
    mask = stocks.columns.get_level_values(1) == stock
    data = stocks.loc[:, mask]
    data.columns = data.columns.droplevel(1)
    return data

# %% [markdown]
# ## Getting indicators demo
# ### Once we have the finalized list of indicators, I will combine them into one function

# %%
# EMA
short_window = 8
long_window = 21
df = get_individual_stock('TSLA')
df[f'EMA_{short_window}'] = TA.EMA(df, short_window)
df[f'EMA_{long_window}'] = TA.EMA(df, long_window)
df[['Close', 'EMA_8', 'EMA_21']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# BBANDS
df = get_individual_stock('TSLA')
df[['BB_UPPER','BB_MIDDLE','BB_LOWER']] = TA.BBANDS(df)
df[['Close', 'BB_UPPER','BB_MIDDLE','BB_LOWER']].plot(figsize = (25,7))

# Keltner Channels
df = get_individual_stock('TSLA')
df[['KC_UPPER', 'KC_LOWER']] = TA.KC(df)
df[['Close', 'KC_UPPER', 'KC_LOWER']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# ADX
df = get_individual_stock('TSLA')
df['ADX'] = TA.ADX(df)
df[['Close','ADX']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
# MACD
df = get_individual_stock('TSLA')
df[['MACD', 'SIGNAL']] = TA.MACD(df)

df[['MACD', 'SIGNAL']].plot(figsize = (25,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df = get_individual_stock('TSLA')
df[['TENKAN','KIJUN','senkou_span_a','SENKOU','CHIKOU']] = TA.ICHIMOKU(df)
df

# %%
df = get_individual_stock('TSLA')
df['SQZMI'] = TA.SQZMI(df)
# Filter the DataFrame based on SQZMI values
false_df = df[df['SQZMI'] == False]
true_df = df[df['SQZMI'] == True]

# Extract the Close values
false_close_values = false_df['Close']
true_close_values = true_df['Close']

# Set the figure size
plt.figure(figsize=(25, 7))  # Adjust the width and height as desired

# Plot the values
plt.plot(false_close_values, color='green', label='SQZMI: False')
plt.scatter(true_df.index, true_close_values, color='red', label='SQZMI: True')
plt.xlabel('Index')
plt.ylabel('Close')
plt.title("Close values with line plot for SQZMI: False and scatter plot for SQZMI: True")
plt.legend()
plt.show()

# %%
TA.RSI(df, period = 21)
# Out:
# Date
# 2017-01-03           NaN
# 2017-01-04    100.000000
# 2017-01-05     97.541975
# 2017-01-06     98.022569
# 2017-01-09     98.360619
#                  ...
# 2023-06-27     62.411027
# 2023-06-28     64.138556
# 2023-06-29     64.496555
# 2023-06-30     65.714445
# 2023-07-03     70.244876
# Name: 21 period RSI, Length: 1635, dtype: float64

# %% [markdown]
# # 3. Determine trading signals for testable indicators (crossovers, etc.)

# %% [markdown]
# # Iterator Class

# %%
# Define a class
class Tester:
    
    def __init__(self, ticker, share_size = 100, initial_cash = 10000, stocks_df = stocks, EMA_len = 50):
        
        self.ticker = ticker
        self.stocks_df = stocks_df
        self.EMA_len = EMA_len
        self.share_size = share_size
        self.initial_cash = initial_cash
        # Call the basic methods in the __init__ constructor to be immediately executed
        
        self.get_individual_stock()
        self.indicators()
        self.signals()
        self.result()
        
    def get_individual_stock(self):
        mask = self.stocks_df.columns.get_level_values(1) == self.ticker
        self.df = stocks.loc[:, mask]
        self.df.columns = self.df.columns.droplevel(1)

    def indicators(self):
        
        # EMA
        self.df[f'EMA_{self.EMA_len}'] = TA.EMA(self.df, self.EMA_len)
        
        # BBANDS
        self.df[['BB_UPPER','BB_MIDDLE','BB_LOWER']] = TA.BBANDS(self.df)

        # Keltner Channels
        self.df[['KC_UPPER', 'KC_LOWER']] = TA.KC(self.df)
        
        # SQZ setup
        self.df['SQZ'] = TA.SQZMI(self.df)
        self.df['SQZ_prev'] = self.df['SQZ'].shift()
        
        # ADX
        self.df['ADX'] = TA.ADX(self.df)
   
    def signals(self):
        
        # EMA Signal logic
        self.df['EMA_Signal'] = 0.0
        self.df['EMA_Signal'] = np.where((self.df['Close'] > self.df[f'EMA_{self.EMA_len}']), 1.0, 0.0)
        
        # BBKC Signal logic
        self.df['BBKC_Signal'] = 0.0
        self.df['BBKC_Signal'] = np.where((self.df['KC_UPPER'] > self.df['BB_UPPER']) & (self.df['BB_LOWER'] > self.df['KC_LOWER']), 1.0, 0.0)
        
        # SQZ Signal logic
        self.df['SQZ_Signal'] = 0.0
        self.df['SQZ_Signal'] = np.where((self.df['SQZ'] == False) & (self.df['SQZ_prev'] == True), 1.0, 0.0)
        
        # ADX Signal logic
        self.df['ADX_Signal'] = 0.0
        self.df['ADX_Signal'] = np.where(self.df['ADX'] > 30, 1.0, 0.0)
        
    def result(self):
        
        # Define eval df columns
        columns = ['Strategy', 'Annualized Return', 'Cumulative Return', 'Annual Volatility', 'Sharpe Ratio']
        eval_df = pd.DataFrame( columns= columns)
        # Define the signal column names
        signal_columns = ['EMA_Signal', 'BBKC_Signal', 'SQZ_Signal', 'ADX_Signal']

        # Generate all combinations of signal columns
        for r in range(1, len(signal_columns) + 1):
            combinations = list(itertools.combinations(signal_columns, r))

            # Iterate over each combination
            for combo in combinations:
                # Perform the desired analysis based on the combination
                selected_columns = list(combo)
                self.df['Main_Signal'] = self.df[selected_columns].prod(axis=1)

                # Entry/Exit logic
                self.df['Entry/Exit'] = self.df['Main_Signal'].diff()
    
                # Performance Metrics
                self.df["Position"] = self.share_size * self.df['Main_Signal']
                self.df["Entry/Exit Position"] = self.df["Position"].diff()
                self.df["Portfolio Holdings"] = self.df["Position"] * self.df['Close']
                self.df["Portfolio Cash"] = self.initial_cash - (self.df['Close'] * self.df['Entry/Exit Position']).cumsum()
                self.df["Portfolio Total"] = self.df["Portfolio Cash"] + self.df["Portfolio Holdings"]
                self.df["Portfolio Daily Returns"] = self.df["Portfolio Total"].pct_change()
                self.df["Portfolio Cumulative Returns"] = (1 + self.df["Portfolio Daily Returns"]).cumprod()
                self.df['Buy And Hold Return'] = (1 + self.df["Close"].pct_change()).cumprod()
                
                # Create a df with performance summary for each combination
                
                # append evaluation metrics to a df as a new row
                ann_ret =  self.df['Portfolio Daily Returns'].mean() * 252
                cum_ret = self.df['Portfolio Cumulative Returns'][-1]
                ann_volat = self.df['Portfolio Daily Returns'].std() * sqrt
                sharpe = ann_ret / ann_volat
                buy_and_hold = self.df['Buy And Hold Return'][-1]
                new_row = {'Strategy' : f'{selected_columns}',
                       'Annualized Return' : ann_ret,
                       'Cumulative Return' : cum_ret,
                       'Annual Volatility' : ann_volat,
                       'Sharpe Ratio' : sharpe,
                       'Buy and Hold': buy_and_hold}
                eval_df = eval_df.append(new_row, ignore_index=True)
                
                filtered_df = eval_df[eval_df['Cumulative Return'] > 1].sort_values('Cumulative Return')
                
        return filtered_df

# %%
info = Tester('TSLA')
info.result()
# Out:
#                                        Strategy  Annualized Return  \
# 4                 ['EMA_Signal', 'BBKC_Signal']           0.015533
# 11  ['EMA_Signal', 'BBKC_Signal', 'ADX_Signal']           0.050121
# 8                 ['BBKC_Signal', 'ADX_Signal']           0.068568
# 1                               ['BBKC_Signal']           0.117121
# 6                  ['EMA_Signal', 'ADX_Signal']           0.230571
# 0                                ['EMA_Signal']           0.256024
# 3                                ['ADX_Signal']           0.267901
#
#     Cumulative Return  Annual Volatility  Sharpe Ratio  Buy and Hold
# 4            1.016367           0.160746      0.096633     19.343289
# 11           1.360580           0.074176      0.675710     19.343289
# 8            1.506213           0.105143      0.652140     19.343289
# 1            1.828181           0.220308      0.531625     19.343289
# 6            3.551073           0.264793      0.870761     19.343289
# 0            4.091780           0.277796      0.921624     19.343289
# 3            4.376707           0.284106      0.942960     19.343289
